# %%
# Used to concatenate our individual seasons data of csv files

# %%
import requests
import pandas as pd
import numpy as np

# %%
adv_02 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_02_03.csv")
adv_03 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_03_04.csv")
adv_04 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_04_05.csv")
adv_05 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_05_06.csv")
adv_06 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_06_07.csv")
adv_07 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_07_08.csv")
adv_08 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_08_09.csv")
adv_09 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_09_10.csv")
adv_10 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_10_11.csv")
adv_11 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_11_12.csv")
adv_12 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_12_13.csv")
adv_13 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_13_14.csv")
adv_14 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_14_15.csv")
adv_15 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_15_16.csv")
adv_16 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_16_17.csv")
adv_17 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_17_18.csv")
adv_18 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_18_19.csv")
adv_19 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_19_20.csv")
adv_20 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_20_21.csv")
adv_21 = pd.read_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data/advanced/advanced_21_22.csv")

# %%
adv_all_years = pd.concat([adv_02, adv_03, adv_04, adv_05, adv_06, adv_07, adv_08, adv_09, adv_10, adv_11, adv_12, adv_13, adv_14, adv_15,adv_16, adv_17, adv_18, adv_19, adv_20, adv_21])

# %%
adv_all_years
# Out:
#        GAME_ID     TEAM_ID      TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY  \
# 0     20200001  1610612753          Magic               ORL       Orlando
# 1     20200001  1610612755          76ers               PHI  Philadelphia
# 2     20200002  1610612739      Cavaliers               CLE     Cleveland
# 3     20200002  1610612758          Kings               SAC    Sacramento
# 4     20200003  1610612759          Spurs               SAS   San Antonio
# ...        ...         ...            ...               ...           ...
# 2455  22101228  1610612765        Pistons               DET       Detroit
# 2456  22101229  1610612756           Suns               PHX       Phoenix
# 2457  22101229  1610612758          Kings               SAC    Sacramento
# 2458  22101230  1610612757  Trail Blazers               POR      Portland
# 2459  22101230  1610612762           Jazz               UTA          Utah
#
#          MIN  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  ...  \
# ...

# %%
adv_all_years.sort_values(['GAME_ID']).to_csv(r"C:\Users\Jo\Google Drive\updated_data\raw_data\adv_all_years.csv", index=False)
